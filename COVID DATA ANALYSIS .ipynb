# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
data =pd.read_csv("/Users/navendrasingh/Downloads/545466-1485103-bundle-archive/covid19_italy_region.csv")

# %%
data.head()
# Out:
#    SNo                 Date Country  RegionCode      RegionName   Latitude  \
# 0    0  2020-02-24T18:00:00     ITA          13         Abruzzo  42.351222
# 1    1  2020-02-24T18:00:00     ITA          17      Basilicata  40.639471
# 2    2  2020-02-24T18:00:00     ITA          18        Calabria  38.905976
# 3    3  2020-02-24T18:00:00     ITA          15        Campania  40.839566
# 4    4  2020-02-24T18:00:00     ITA           8  Emilia-Romagna  44.494367
#
#    Longitude  HospitalizedPatients  IntensiveCarePatients  \
# 0  13.398438                     0                      0
# 1  15.805148                     0                      0
# 2  16.594402                     0                      0
# 3  14.250850                     0                      0
# 4  11.341721                    10                      2
#
#    TotalHospitalizedPatients  HomeConfinement  CurrentPositiveCases  \
# 0                          0                0                     0
# ...

# %%
data.columns
# Out:
# Index(['SNo', 'Date', 'Country', 'RegionCode', 'RegionName', 'Latitude',
#        'Longitude', 'HospitalizedPatients', 'IntensiveCarePatients',
#        'TotalHospitalizedPatients', 'HomeConfinement', 'CurrentPositiveCases',
#        'NewPositiveCases', 'Recovered', 'Deaths', 'TotalPositiveCases',
#        'TestsPerformed'],
#       dtype='object')

# %%
data.describe()
# Out:
#               SNo   RegionCode     Latitude    Longitude  \
# count  4242.00000  4242.000000  4242.000000  4242.000000
# mean   2120.50000    11.857143    43.046293    12.225955
# std    1224.70425     6.274538     2.489074     2.659261
# min       0.00000     1.000000    38.115697     7.320149
# 25%    1060.25000     7.000000    41.125596    11.121231
# 50%    2120.50000    12.000000    43.616760    12.388247
# 75%    3180.75000    17.000000    45.434905    13.768136
# max    4241.00000    22.000000    46.499335    16.867367
#
#        HospitalizedPatients  IntensiveCarePatients  TotalHospitalizedPatients  \
# count           4242.000000            4242.000000                4242.000000
# mean             399.320368              44.786657                 444.107025
# std             1248.978546             132.633550                1376.869330
# min                0.000000               0.000000                   0.000000
# ...

# %%
x=data.isnull().sum()

# %%
data.drop(x)
# Out:
#        SNo                 Date Country  RegionCode             RegionName  \
# 1        1  2020-02-24T18:00:00     ITA          17             Basilicata
# 2        2  2020-02-24T18:00:00     ITA          18               Calabria
# 3        3  2020-02-24T18:00:00     ITA          15               Campania
# 4        4  2020-02-24T18:00:00     ITA           8         Emilia-Romagna
# 5        5  2020-02-24T18:00:00     ITA           6  Friuli Venezia Giulia
# ...    ...                  ...     ...         ...                    ...
# 4237  4237  2020-09-12T17:00:00     ITA          19                Sicilia
# 4238  4238  2020-09-12T17:00:00     ITA           9                Toscana
# 4239  4239  2020-09-12T17:00:00     ITA          10                 Umbria
# 4240  4240  2020-09-12T17:00:00     ITA           2          Valle d'Aosta
# 4241  4241  2020-09-12T17:00:00     ITA           5                 Veneto
#
# ...

# %%
data.isnull().sum()
# Out:
# SNo                             0
# Date                            0
# Country                         0
# RegionCode                      0
# RegionName                      0
# Latitude                        0
# Longitude                       0
# HospitalizedPatients            0
# IntensiveCarePatients           0
# TotalHospitalizedPatients       0
# HomeConfinement                 0
# CurrentPositiveCases            0
# NewPositiveCases                0
# Recovered                       0
# Deaths                          0
# TotalPositiveCases              0
# TestsPerformed               1155
# dtype: int64

# %%
sns.regplot(x="RegionCode",y="TotalPositiveCases",data=data)

# %%
data.columns
# Out:
# Index(['SNo', 'Date', 'Country', 'RegionCode', 'RegionName', 'Latitude',
#        'Longitude', 'HospitalizedPatients', 'IntensiveCarePatients',
#        'TotalHospitalizedPatients', 'HomeConfinement', 'CurrentPositiveCases',
#        'NewPositiveCases', 'Recovered', 'Deaths', 'TotalPositiveCases',
#        'TestsPerformed'],
#       dtype='object')

# %%
sns.pairplot(data=data)

# %%
data =pd.read_csv("/Users/navendrasingh/Downloads/545466-1485103-bundle-archive/covid19_italy_region.csv")

# %%
sns.relplot(x="TotalPositiveCases",y="HomeConfinement",data=data,kind="line")
