# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
os.listdir(os.getcwd())
data=pd.read_csv('Ecommerce Purchases.csv')
data
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
#** How many rows and columns are there? **

# %%
10000 rows × 14 columns
# Out:
#   File "<ipython-input-3-4ac28067858a>", line 1
#     10000 rows × 14 columns
#              ^
# SyntaxError: invalid syntax

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  object
#  1   Lot               10000 non-null  object
#  2   AM or PM          10000 non-null  object
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  int64
#  6   CC Exp Date       10000 non-null  object
#  7   CC Security Code  10000 non-null  int64
#  8   CC Provider       10000 non-null  object
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  object
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  object
#  13  Purchase Price    10000 non-null  float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %%
#** What is the average Purchase Price? **
data['Purchase Price'].sum()//data.groupby("Address").count()

# %%
#** What were the highest and lowest purchase prices? **

# %%
data['Purchase Price'].max()
# Out:
# 99.99

# %%
data['Purchase Price'].min()
# Out:
# 0.0

# %%
#** How many people have English 'en' as their Language of choice on the website? **

# %%
data.groupby('Language').count()
# Out:
#           Address   Lot  AM or PM  Browser Info  Company  Credit Card  \
# Language
# de           1155  1155      1155          1155     1155         1155
# el           1137  1137      1137          1137     1137         1137
# en           1098  1098      1098          1098     1098         1098
# es           1095  1095      1095          1095     1095         1095
# fr           1097  1097      1097          1097     1097         1097
# it           1086  1086      1086          1086     1086         1086
# pt           1118  1118      1118          1118     1118         1118
# ru           1155  1155      1155          1155     1155         1155
# zh           1059  1059      1059          1059     1059         1059
#
#           CC Exp Date  CC Security Code  CC Provider  Email   Job  IP Address  \
# Language
# de               1155              1155         1155   1155  1155        1155
# el               1137              1137         1137   1137  1137        1137
# ...

# %%
data.groupby('Language')

# %%
#** How many people have the job title of "Lawyer" ? **

data.groupby('Job').count()
# Out:
#                                   Address  Lot  AM or PM  Browser Info  \
# Job
# Academic librarian                     11   11        11            11
# Accommodation manager                  17   17        17            17
# Accountant, chartered                  20   20        20            20
# Accountant, chartered certified        18   18        18            18
# Accountant, chartered management       15   15        15            15
# ...                                   ...  ...       ...           ...
# Water quality scientist                18   18        18            18
# Web designer                           20   20        20            20
# Wellsite geologist                     24   24        24            24
# Writer                                 10   10        10            10
# Youth worker                           18   18        18            18
#
#                                   Company  Credit Card  CC Exp Date  \
# Job
# ...

# %%
#** How many people made the purchase during the AM and how many people made the purchase during PM ? **
data.groupby('AM or PM').count()
# Out:
#           Address   Lot  Browser Info  Company  Credit Card  CC Exp Date  \
# AM or PM
# AM           4932  4932          4932     4932         4932         4932
# PM           5068  5068          5068     5068         5068         5068
#
#           CC Security Code  CC Provider  Email   Job  IP Address  Language  \
# AM or PM
# AM                    4932         4932   4932  4932        4932      4932
# PM                    5068         5068   5068  5068        5068      5068
#
#           Purchase Price
# AM or PM
# AM                  4932
# PM                  5068

# %%
data.groupby('AM or PM').sum()
# Out:
#            Credit Card  CC Security Code  Purchase Price
# AM or PM
# AM        1.163761e+19         4406081.0       247519.87
# PM        1.177613e+19         4666097.0       255953.15

# %%
x=data.groupby('AM or PM')

# %%
x.count()
# Out:
#           Address   Lot  Browser Info  Company  Credit Card  CC Exp Date  \
# AM or PM
# AM           4932  4932          4932     4932         4932         4932
# PM           5068  5068          5068     5068         5068         5068
#
#           CC Security Code  CC Provider  Email   Job  IP Address  Language  \
# AM or PM
# AM                    4932         4932   4932  4932        4932      4932
# PM                    5068         5068   5068  5068        5068      5068
#
#           Purchase Price
# AM or PM
# AM                  4932
# PM                  5068

# %%
#** What is the email of the person with the following Credit Card Number: 4926535242672853 **

# %%
data['Credit Card'] == 4926535242672853
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Name: Credit Card, Length: 10000, dtype: bool

# %%
mpg = sns.load_dataset("mpg")

# %%
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
x=mpg.groupby("model_year")

# %%
x.count()
# Out:
#             mpg  cylinders  displacement  horsepower  weight  acceleration  \
# model_year
# 70           29         29            29          29      29            29
# 71           28         28            28          27      28            28
# 72           28         28            28          28      28            28
# 73           40         40            40          40      40            40
# 74           27         27            27          26      27            27
# 75           30         30            30          30      30            30
# 76           34         34            34          34      34            34
# 77           28         28            28          28      28            28
# 78           36         36            36          36      36            36
# 79           29         29            29          29      29            29
# 80           29         29            29          27      29            29
# ...

# %%
tips = sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.min()
# Out:
# total_bill      3.07
# tip                1
# sex           Female
# smoker            No
# day              Fri
# time          Dinner
# size               1
# dtype: object

# %%
# Load the Pandas libraries with alias 'pd' 
import pandas as pd 
# Read data from file 'filename.csv' 
# (in the same directory that your python process is based)
# Control delimiters, rows, column names with read_csv (see later) 
data = pd.read_csv("/Users/navendrasingh/Downloads/Order-CSV-5.csv") 
# Preview the first 5 lines of the loaded data 
data.head(30)
# Out:
#       Ordered On                           Shipment ID       ORDER ITEM ID  \
# 0   Aug 16, 2020  d827a491-404b-45d1-8104-b52d8f76dc03  '11944082129825500
# 1   Aug 16, 2020  804e3ac3-757d-452c-b53e-05169e6d8baf  '11944204288098100
# 2   Aug 16, 2020  f2ebce19-0168-4c88-bba2-eb07b7f4e62f  '11944480114877100
# 3   Aug 17, 2020  722e4c63-fdb9-4088-8118-28da2b8223bc  '11944898361770700
# 4   Aug 17, 2020  40d92cdb-a82e-4fac-b8b2-7f14dcb5a895  '11945014104271300
# 5   Aug 17, 2020  142a131a-e3df-4b35-be3e-e44c5498080f  '11945092184164000
# 6   Aug 09, 2020  6ebe6587-5cf3-4c89-bda5-6070203c4cde  '11938482421055601
# 7   Aug 17, 2020  bd37ecdd-eeb6-4f4f-a949-27b220e2589b  '11945148150233500
# 8   Aug 17, 2020  afcc11cf-d621-4728-8469-c6b8ad5a7748  '11945138810322400
# 9   Aug 17, 2020  9e857513-8145-47d9-8564-b7e2fbc4a4df  '11945222970475200
# 10  Aug 17, 2020  cb404def-5eb7-451d-b049-d79ddf286809  '11945240717265000
# ...

# %%
data.drop(columns=['Style Code','Aisle','Rack No','Weight(gm)','Length(cm)','Breadth(cm)','Height(cm)'])
# Out:
#                                     Channel SKU Title    SKU Code  \
# 0                Bata Slippers Blue 7 FG-24 8779619-7   8779619-7
# 1   Bata Corporate Loafers Slip On For Men Black 4...  8516629-10
# 2   Bata Slip On For Men Black 9 851-6629 8516629-...   8516629-9
# 3   Bata Slip On For Men Black 8 bata-851-6529-sli...   8516629-8
# 4   Bata Corporate Derby Lace Up Lace Up For Men B...   8216116-9
# 5   Bata Corporate Loafers Slip On For Men Black 4...   8516217-6
# 6   Bata Corporate Loafers Slip On Slip On For Men...  8516629-11
# 7       Bata Derby For Men Black 8 8216116 8216116--8   8216116-8
# 8   Bata Men's Formal Slip On For Men Black 43 FOR...   8516217-9
# 9                Bata Slippers Blue 8 FG-24 8779619-8   8779619-8
# 10  Bata Lace Up For Men BLACK 42 653532 8216332--...   8216332-8
# 11       Bata Men Brown Sandals 7 851-4339 8514339--7   8514339-7
# 12  Bata Slip On For Men Black 7 851-6629 8516629-...   8516629-7
# ...
